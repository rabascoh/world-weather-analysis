# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | mount isa
# Processing Record 5 of Set 1 | along
# Processing Record 6 of Set 1 | belaya gora
# Processing Record 7 of Set 1 | de-kastri
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | andra
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | erdenet
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | colombo
# Processing Record 15 of Set 1 | valentin gomez farias
# Processing Record 16 of Set 1 | constantine
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | qasigiannguit
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | fernley
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | yambio
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | tilichiki
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | pangnirtung
# Processing Record 34 of Set 1 | riyadh
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | ola
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | trairi
# Processing Record 41 of Set 1 | tallahassee
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | svetlaya
# Processing Record 45 of Set 1 | boa vista
# Processing Record 46 of Set 1 | katsuura
# Processing Record 47 of Set 1 | yagodnoye
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | trat
# Processing Record 50 of Set 1 | cockburn town
# Processing Record 1 of Set 2 | andenes
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | glenwood springs
# Processing Record 5 of Set 2 | portland
# Processing Record 6 of Set 2 | sitka
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | labrea
# Processing Record 9 of Set 2 | vardo
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | alugan
# Processing Record 12 of Set 2 | chapais
# Processing Record 13 of Set 2 | alofi
# Processing Record 14 of Set 2 | marawi
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | yeppoon
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | laem sing
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | aklavik
# Processing Record 27 of Set 2 | kavaratti
# Processing Record 28 of Set 2 | qaqortoq
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | coos bay
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | mungwi
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | obluche
# City not found. Skipping...
# Processing Record 37 of Set 2 | sovetskiy
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | sao gabriel da cachoeira
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | rio grande
# Processing Record 44 of Set 2 | isangel
# Processing Record 45 of Set 2 | bentiu
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | pontes e lacerda
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | grindavik
# Processing Record 1 of Set 3 | laguna
# Processing Record 2 of Set 3 | lebedyn
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | nyalikungu
# Processing Record 7 of Set 3 | mangrol
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | okha
# Processing Record 10 of Set 3 | buritis
# Processing Record 11 of Set 3 | shahr-e babak
# Processing Record 12 of Set 3 | celestun
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | palasa
# Processing Record 15 of Set 3 | kaa-khem
# Processing Record 16 of Set 3 | laureles
# Processing Record 17 of Set 3 | tuy hoa
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | san lazaro
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | cayenne
# Processing Record 25 of Set 3 | camana
# Processing Record 26 of Set 3 | uniontown
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 3 | cabra
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | murgab
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | mogok
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | mujiayingzi
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | nantucket
# Processing Record 43 of Set 3 | hals
# Processing Record 44 of Set 3 | mehamn
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | newport
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | honningsvag
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | kawalu
# Processing Record 1 of Set 4 | nokaneng
# Processing Record 2 of Set 4 | prince rupert
# Processing Record 3 of Set 4 | ust-maya
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | tahta
# Processing Record 6 of Set 4 | kaseda
# Processing Record 7 of Set 4 | alliance
# Processing Record 8 of Set 4 | port harcourt
# Processing Record 9 of Set 4 | kloulklubed
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | rio gallegos
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | vila franca do campo
# Processing Record 14 of Set 4 | dhidhdhoo
# Processing Record 15 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 4 | kyra
# Processing Record 17 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 4 | romny
# Processing Record 19 of Set 4 | jacqueville
# Processing Record 20 of Set 4 | port hedland
# Processing Record 21 of Set 4 | imeni stepana razina
# Processing Record 22 of Set 4 | vezirkopru
# Processing Record 23 of Set 4 | helong
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | eydhafushi
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | stykkisholmur
# Processing Record 31 of Set 4 | bangonay
# Processing Record 32 of Set 4 | bourail
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | wilmington
# Processing Record 35 of Set 4 | brae
# Processing Record 36 of Set 4 | te anau
# Processing Record 37 of Set 4 | lima
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | dikson
# Processing Record 40 of Set 4 | shubarkuduk
# Processing Record 41 of Set 4 | turayf
# Processing Record 42 of Set 4 | codajas
# Processing Record 43 of Set 4 | manta
# Processing Record 44 of Set 4 | mataura
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | kutum
# Processing Record 47 of Set 4 | georgetown
# Processing Record 48 of Set 4 | dryden
# Processing Record 49 of Set 4 | puerto baquerizo moreno
# Processing Record 50 of Set 4 | kuching
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | santa lucia
# Processing Record 3 of Set 5 | hanumangarh
# Processing Record 4 of Set 5 | labuan
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | santiago de cuba
# Processing Record 7 of Set 5 | biak
# Processing Record 8 of Set 5 | ferrandina
# Processing Record 9 of Set 5 | katherine
# Processing Record 10 of Set 5 | marsh harbour
# Processing Record 11 of Set 5 | maunabo
# Processing Record 12 of Set 5 | tastur
# Processing Record 13 of Set 5 | vestmannaeyjar
# Processing Record 14 of Set 5 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | gambo
# Processing Record 16 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 5 | santa cruz
# Processing Record 18 of Set 5 | sturgis
# Processing Record 19 of Set 5 | richards bay
# Processing Record 20 of Set 5 | qui nhon
# Processing Record 21 of Set 5 | atikokan
# Processing Record 22 of Set 5 | barrow
# Processing Record 23 of Set 5 | dhamrai
# Processing Record 24 of Set 5 | dzhebariki-khaya
# Processing Record 25 of Set 5 | funadhoo
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | podporozhye
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | camacha
# Processing Record 30 of Set 5 | ustka
# Processing Record 31 of Set 5 | palmer
# Processing Record 32 of Set 5 | victoria
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | ilhabela
# Processing Record 35 of Set 5 | oriximina
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | yanam
# Processing Record 38 of Set 5 | zhoucheng
# Processing Record 39 of Set 5 | oktyabrskoye
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | hami
# Processing Record 43 of Set 5 | diego de almagro
# Processing Record 44 of Set 5 | bosaso
# Processing Record 45 of Set 5 | eston
# Processing Record 46 of Set 5 | bowen
# Processing Record 47 of Set 5 | anito
# Processing Record 48 of Set 5 | road town
# Processing Record 49 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 5 | verdalsora
# City not found. Skipping...
# Processing Record 1 of Set 6 | huescar
# Processing Record 2 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | tunceli
# Processing Record 5 of Set 6 | senhor do bonfim
# Processing Record 6 of Set 6 | youghal
# Processing Record 7 of Set 6 | cabadiangan
# Processing Record 8 of Set 6 | raudeberg
# Processing Record 9 of Set 6 | fairbanks
# Processing Record 10 of Set 6 | avera
# Processing Record 11 of Set 6 | lagoa
# Processing Record 12 of Set 6 | aykhal
# Processing Record 13 of Set 6 | tres arroyos
# Processing Record 14 of Set 6 | lindi
# Processing Record 15 of Set 6 | santo antonio do ica
# Processing Record 16 of Set 6 | jurilovca
# Processing Record 17 of Set 6 | whyalla
# Processing Record 18 of Set 6 | vila
# Processing Record 19 of Set 6 | bom jesus da lapa
# Processing Record 20 of Set 6 | yatou
# Processing Record 21 of Set 6 | dutse
# Processing Record 22 of Set 6 | lunglei
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | fortuna
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | margate
# Processing Record 27 of Set 6 | shimoda
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | wukari
# Processing Record 30 of Set 6 | cleveland
# Processing Record 31 of Set 6 | mamakan
# Processing Record 32 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 6 | pauini
# Processing Record 34 of Set 6 | rubtsovsk
# Processing Record 35 of Set 6 | pisco
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | jardim
# Processing Record 38 of Set 6 | paldiski
# Processing Record 39 of Set 6 | ierapetra
# Processing Record 40 of Set 6 | vagur
# Processing Record 41 of Set 6 | severo-kurilsk
# Processing Record 42 of Set 6 | dolores
# Processing Record 43 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 6 | goderich
# Processing Record 45 of Set 6 | jablanica
# Processing Record 46 of Set 6 | nanortalik
# Processing Record 47 of Set 6 | souillac
# Processing Record 48 of Set 6 | egvekinot
# Processing Record 49 of Set 6 | boli
# Processing Record 50 of Set 6 | digby
# Processing Record 1 of Set 7 | borogontsy
# Processing Record 2 of Set 7 | tarakan
# Processing Record 3 of Set 7 | kibre mengist
# Processing Record 4 of Set 7 | maceio
# Processing Record 5 of Set 7 | atlanta
# Processing Record 6 of Set 7 | makakilo city
# Processing Record 7 of Set 7 | millinocket
# Processing Record 8 of Set 7 | kita
# Processing Record 9 of Set 7 | fergus
# Processing Record 10 of Set 7 | nyrob
# Processing Record 11 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 12 of Set 7 | horizontina
# Processing Record 13 of Set 7 | qujing
# Processing Record 14 of Set 7 | nizwa
# Processing Record 15 of Set 7 | kavieng
# Processing Record 16 of Set 7 | la asuncion
# Processing Record 17 of Set 7 | parras
# City not found. Skipping...
# Processing Record 18 of Set 7 | mandurah
# Processing Record 19 of Set 7 | flinders
# Processing Record 20 of Set 7 | araceli
# Processing Record 21 of Set 7 | ust-tsilma
# Processing Record 22 of Set 7 | loandjili
# Processing Record 23 of Set 7 | moose factory
# Processing Record 24 of Set 7 | sabha
# Processing Record 25 of Set 7 | magadan
# Processing Record 26 of Set 7 | san quintin
# Processing Record 27 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | aden
# Processing Record 30 of Set 7 | linxia
# Processing Record 31 of Set 7 | forssa
# Processing Record 32 of Set 7 | talnakh
# Processing Record 33 of Set 7 | kailua
# Processing Record 34 of Set 7 | talara
# Processing Record 35 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 36 of Set 7 | ixtapa
# Processing Record 37 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | yellowknife
# Processing Record 39 of Set 7 | champerico
# Processing Record 40 of Set 7 | bandarbeyla
# Processing Record 41 of Set 7 | zerbst
# Processing Record 42 of Set 7 | wahiawa
# Processing Record 43 of Set 7 | lamu
# Processing Record 44 of Set 7 | campoverde
# Processing Record 45 of Set 7 | biltine
# Processing Record 46 of Set 7 | livingston
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | rypefjord
# Processing Record 49 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 50 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 8 | bemidji
# Processing Record 2 of Set 8 | brest
# Processing Record 3 of Set 8 | santa cruz del norte
# Processing Record 4 of Set 8 | puerto carreno
# Processing Record 5 of Set 8 | moron
# Processing Record 6 of Set 8 | morondava
# Processing Record 7 of Set 8 | buala
# Processing Record 8 of Set 8 | tighnabruaich
# Processing Record 9 of Set 8 | kudahuvadhoo
# Processing Record 10 of Set 8 | houma
# Processing Record 11 of Set 8 | baruun-urt
# Processing Record 12 of Set 8 | wajima
# Processing Record 13 of Set 8 | pop
# Processing Record 14 of Set 8 | syamzha
# Processing Record 15 of Set 8 | mayor pablo lagerenza
# Processing Record 16 of Set 8 | kaka
# Processing Record 17 of Set 8 | moses lake
# Processing Record 18 of Set 8 | uray
# Processing Record 19 of Set 8 | port maria
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | rocha
# Processing Record 22 of Set 8 | bukan
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | rosetta
# Processing Record 25 of Set 8 | loa janan
# Processing Record 26 of Set 8 | machico
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | bakhmach
# Processing Record 29 of Set 8 | saint-leu
# Processing Record 30 of Set 8 | prince albert
# Processing Record 31 of Set 8 | thano bula khan
# City not found. Skipping...
# Processing Record 32 of Set 8 | sinnamary
# Processing Record 33 of Set 8 | saldanha
# Processing Record 34 of Set 8 | oranjemund
# Processing Record 35 of Set 8 | indianola
# Processing Record 36 of Set 8 | benjamin constant
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | celina
# Processing Record 39 of Set 8 | awjilah
# Processing Record 40 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 41 of Set 8 | porbandar
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | yerbogachen
# Processing Record 44 of Set 8 | sujiatun
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | takoradi
# Processing Record 47 of Set 8 | ejea de los caballeros
# Processing Record 48 of Set 8 | cabedelo
# Processing Record 49 of Set 8 | tres lagoas
# Processing Record 50 of Set 8 | kencong
# Processing Record 1 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 9 | florida
# Processing Record 3 of Set 9 | mount gambier
# Processing Record 4 of Set 9 | kang
# Processing Record 5 of Set 9 | orneta
# Processing Record 6 of Set 9 | taksimo
# Processing Record 7 of Set 9 | tautira
# Processing Record 8 of Set 9 | soyo
# Processing Record 9 of Set 9 | byron bay
# Processing Record 10 of Set 9 | terney
# Processing Record 11 of Set 9 | marmora
# Processing Record 12 of Set 9 | la rioja
# Processing Record 13 of Set 9 | gravdal
# Processing Record 14 of Set 9 | kodinar
# Processing Record 15 of Set 9 | shymkent
# Processing Record 16 of Set 9 | nizhyn
# Processing Record 17 of Set 9 | namtsy
# Processing Record 18 of Set 9 | axim
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | pangai
# Processing Record 21 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 9 | nyuksenitsa
# Processing Record 23 of Set 9 | cabinda
# Processing Record 24 of Set 9 | kjopsvik
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | sainte-marie
# Processing Record 27 of Set 9 | gat
# Processing Record 28 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 30 of Set 9 | kaduy
# Processing Record 31 of Set 9 | lakota
# Processing Record 32 of Set 9 | oneonta
# Processing Record 33 of Set 9 | paamiut
# Processing Record 34 of Set 9 | gorontalo
# Processing Record 35 of Set 9 | bambous virieux
# Processing Record 36 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 9 | antofagasta
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | porto novo
# Processing Record 40 of Set 9 | zheleznodorozhnyy
# Processing Record 41 of Set 9 | sanchor
# Processing Record 42 of Set 9 | ribas do rio pardo
# Processing Record 43 of Set 9 | lugovoy
# Processing Record 44 of Set 9 | chuy
# Processing Record 45 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 9 | luderitz
# Processing Record 47 of Set 9 | taebla
# Processing Record 48 of Set 9 | quesnel
# Processing Record 49 of Set 9 | ruteng
# Processing Record 50 of Set 9 | parvatipuram
# Processing Record 1 of Set 10 | puerto escondido
# Processing Record 2 of Set 10 | svetlogorsk
# Processing Record 3 of Set 10 | kundarki
# City not found. Skipping...
# Processing Record 4 of Set 10 | high prairie
# Processing Record 5 of Set 10 | staritsa
# Processing Record 6 of Set 10 | skalat
# Processing Record 7 of Set 10 | krasnoshchekovo
# Processing Record 8 of Set 10 | asosa
# Processing Record 9 of Set 10 | yumen
# Processing Record 10 of Set 10 | waingapu
# Processing Record 11 of Set 10 | firminy
# Processing Record 12 of Set 10 | hurghada
# Processing Record 13 of Set 10 | linao
# Processing Record 14 of Set 10 | aquiraz
# Processing Record 15 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 10 | ruidoso
# Processing Record 17 of Set 10 | javanrud
# Processing Record 18 of Set 10 | warrington
# Processing Record 19 of Set 10 | hirara
# Processing Record 20 of Set 10 | ostrovnoy
# Processing Record 21 of Set 10 | ewa beach
# Processing Record 22 of Set 10 | alta floresta
# Processing Record 23 of Set 10 | kitgum
# Processing Record 24 of Set 10 | sumenep
# Processing Record 25 of Set 10 | angren
# Processing Record 26 of Set 10 | amga
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | puerto del rosario
# Processing Record 29 of Set 10 | general roca
# Processing Record 30 of Set 10 | ponta delgada
# Processing Record 31 of Set 10 | nazarovo
# Processing Record 32 of Set 10 | xiaoweizhai
# Processing Record 33 of Set 10 | leiva
# Processing Record 34 of Set 10 | koupela
# Processing Record 35 of Set 10 | forestville
# Processing Record 36 of Set 10 | khash
# Processing Record 37 of Set 10 | clyde river
# Processing Record 38 of Set 10 | makat
# Processing Record 39 of Set 10 | rawson
# Processing Record 40 of Set 10 | lufilufi
# Processing Record 41 of Set 10 | mlandizi
# Processing Record 42 of Set 10 | naze
# Processing Record 43 of Set 10 | veraval
# Processing Record 44 of Set 10 | pirassununga
# Processing Record 45 of Set 10 | mendi
# Processing Record 46 of Set 10 | kamaishi
# Processing Record 47 of Set 10 | necochea
# Processing Record 48 of Set 10 | nakhon phanom
# Processing Record 49 of Set 10 | itarema
# Processing Record 50 of Set 10 | husavik
# Processing Record 1 of Set 11 | thunder bay
# Processing Record 2 of Set 11 | acajutla
# Processing Record 3 of Set 11 | key west
# Processing Record 4 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 11 | amapa
# Processing Record 7 of Set 11 | zhigalovo
# Processing Record 8 of Set 11 | sosnovskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | qandala
# Processing Record 10 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 11 | kruisfontein
# Processing Record 12 of Set 11 | dali
# Processing Record 13 of Set 11 | vanimo
# Processing Record 14 of Set 11 | teguldet
# Processing Record 15 of Set 11 | lingyuan
# Processing Record 16 of Set 11 | bridlington
# Processing Record 17 of Set 11 | vihti
# Processing Record 18 of Set 11 | ust-kut
# Processing Record 19 of Set 11 | northam
# Processing Record 20 of Set 11 | stornoway
# Processing Record 21 of Set 11 | saint quentin
# City not found. Skipping...
# Processing Record 22 of Set 11 | contai
# Processing Record 23 of Set 11 | hofn
# Processing Record 24 of Set 11 | killybegs
# Processing Record 25 of Set 11 | havre-saint-pierre
# Processing Record 26 of Set 11 | launceston
# Processing Record 27 of Set 11 | skrunda
# Processing Record 28 of Set 11 | hays
# Processing Record 29 of Set 11 | chauk
# Processing Record 30 of Set 11 | kerrville
# Processing Record 31 of Set 11 | sawtell
# Processing Record 32 of Set 11 | serebryansk
# Processing Record 33 of Set 11 | lorengau
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | roald
# Processing Record 36 of Set 11 | malanje
# Processing Record 37 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 11 | bentong
# Processing Record 39 of Set 11 | zorritos
# Processing Record 40 of Set 11 | tarko-sale
# Processing Record 41 of Set 11 | yarmouth
# Processing Record 42 of Set 11 | debica
# Processing Record 43 of Set 11 | campbellsville
# Processing Record 44 of Set 11 | banda aceh
# Processing Record 45 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 11 | padang
# Processing Record 47 of Set 11 | tongliao
# Processing Record 48 of Set 11 | sakakah
# Processing Record 49 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 12 | corrente
# Processing Record 2 of Set 12 | lebedinyy
# Processing Record 3 of Set 12 | maun
# Processing Record 4 of Set 12 | cap malheureux
# Processing Record 5 of Set 12 | komsomolskiy
# Processing Record 6 of Set 12 | macedo de cavaleiros
# Processing Record 7 of Set 12 | north bend
# Processing Record 8 of Set 12 | aksarka
# Processing Record 9 of Set 12 | nishihara
# Processing Record 10 of Set 12 | port blair
# Processing Record 11 of Set 12 | bantou
# Processing Record 12 of Set 12 | guerrero negro
# Processing Record 13 of Set 12 | gimli
# Processing Record 14 of Set 12 | bombay
# Processing Record 15 of Set 12 | ludhiana
# Processing Record 16 of Set 12 | mastung
# Processing Record 17 of Set 12 | jibuti
# Processing Record 18 of Set 12 | manavalakurichi
# Processing Record 19 of Set 12 | ahuimanu
# Processing Record 20 of Set 12 | mnogovershinnyy
# Processing Record 21 of Set 12 | ziro
# Processing Record 22 of Set 12 | maniitsoq
# Processing Record 23 of Set 12 | tete
# Processing Record 24 of Set 12 | severnoye
# Processing Record 25 of Set 12 | maldonado
# Processing Record 26 of Set 12 | rzhev
# Processing Record 27 of Set 12 | christchurch
# Processing Record 28 of Set 12 | altamira
# Processing Record 29 of Set 12 | banfora
# Processing Record 30 of Set 12 | manama
# Processing Record 31 of Set 12 | wad madani
# Processing Record 32 of Set 12 | berezovyy
# Processing Record 33 of Set 12 | villa altagracia
# Processing Record 34 of Set 12 | geraldton
# Processing Record 35 of Set 12 | sorland
# Processing Record 36 of Set 12 | miles city
# Processing Record 37 of Set 12 | orlik
# Processing Record 38 of Set 12 | lagos
# Processing Record 39 of Set 12 | varkaus
# Processing Record 40 of Set 12 | hamilton
# Processing Record 41 of Set 12 | turukhansk
# Processing Record 42 of Set 12 | meulaboh
# Processing Record 43 of Set 12 | umm lajj
# Processing Record 44 of Set 12 | leningradskiy
# Processing Record 45 of Set 12 | russell
# Processing Record 46 of Set 12 | dharmanagar
# Processing Record 47 of Set 12 | inhambane
# Processing Record 48 of Set 12 | rokytne
# Processing Record 49 of Set 12 | tuskegee
# Processing Record 50 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 1 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 3 of Set 13 | sao raimundo das mangabeiras
# Processing Record 4 of Set 13 | pasni
# Processing Record 5 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 13 | jalpan
# Processing Record 7 of Set 13 | ajdabiya
# Processing Record 8 of Set 13 | nicoya
# Processing Record 9 of Set 13 | honiara
# Processing Record 10 of Set 13 | koungou
# Processing Record 11 of Set 13 | rocky mountain house
# Processing Record 12 of Set 13 | casa grande
# Processing Record 13 of Set 13 | khorixas
# Processing Record 14 of Set 13 | kapoeta
# Processing Record 15 of Set 13 | lasa
# Processing Record 16 of Set 13 | tecoanapa
# Processing Record 17 of Set 13 | suoyarvi
# Processing Record 18 of Set 13 | alta
# Processing Record 19 of Set 13 | lazaro cardenas
# Processing Record 20 of Set 13 | la ronge
# Processing Record 21 of Set 13 | peniche
# Processing Record 22 of Set 13 | bukachacha
# Processing Record 23 of Set 13 | doba
# Processing Record 24 of Set 13 | lewisporte
# Processing Record 25 of Set 13 | mangan
# Processing Record 26 of Set 13 | labuhan
# Processing Record 27 of Set 13 | gilbues
# Processing Record 28 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 13 | mancio lima
# Processing Record 30 of Set 13 | tigil
# Processing Record 31 of Set 13 | salalah
# Processing Record 32 of Set 13 | burgos
# Processing Record 33 of Set 13 | gidole
# Processing Record 34 of Set 13 | syracuse
# Processing Record 35 of Set 13 | anadyr
# Processing Record 36 of Set 13 | caravelas
# Processing Record 37 of Set 13 | carballo
# Processing Record 38 of Set 13 | tigre
# Processing Record 39 of Set 13 | great falls
# Processing Record 40 of Set 13 | dzialdowo
# Processing Record 41 of Set 13 | soteapan
# Processing Record 42 of Set 13 | salinas
# Processing Record 43 of Set 13 | jieshou
# Processing Record 44 of Set 13 | kirakira
# Processing Record 45 of Set 13 | klaksvik
# Processing Record 46 of Set 13 | roma
# Processing Record 47 of Set 13 | hay river
# Processing Record 48 of Set 13 | half moon bay
# Processing Record 49 of Set 13 | kyren
# Processing Record 50 of Set 13 | roshni-chu
# Processing Record 1 of Set 14 | smithers
# Processing Record 2 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 14 | san vicente
# Processing Record 4 of Set 14 | coahuayana
# Processing Record 5 of Set 14 | odienne
# Processing Record 6 of Set 14 | marivan
# Processing Record 7 of Set 14 | santarem
# Processing Record 8 of Set 14 | uyemskiy
# Processing Record 9 of Set 14 | haines junction
# Processing Record 10 of Set 14 | ituiutaba
# Processing Record 11 of Set 14 | novyy urengoy
# Processing Record 12 of Set 14 | seoul
# Processing Record 13 of Set 14 | tanete
# Processing Record 14 of Set 14 | atsipopoulon
# Processing Record 15 of Set 14 | harrison
# Processing Record 16 of Set 14 | boddam
# Processing Record 17 of Set 14 | beitbridge
# Processing Record 18 of Set 14 | moussoro
# Processing Record 19 of Set 14 | lidkoping
# Processing Record 20 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 21 of Set 14 | bereda
# Processing Record 22 of Set 14 | standerton
# Processing Record 23 of Set 14 | vostok
# Processing Record 24 of Set 14 | mayo
# Processing Record 25 of Set 14 | camabatela
# Processing Record 26 of Set 14 | olesnica
# Processing Record 27 of Set 14 | newberry
# Processing Record 28 of Set 14 | tabou
# Processing Record 29 of Set 14 | kenai
# Processing Record 30 of Set 14 | los llanos de aridane
# Processing Record 31 of Set 14 | buraydah
# Processing Record 32 of Set 14 | pozo colorado
# Processing Record 33 of Set 14 | hobyo
# Processing Record 34 of Set 14 | krasnoselkup
# Processing Record 35 of Set 14 | maumere
# Processing Record 36 of Set 14 | namatanai
# Processing Record 37 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 14 | balakhninskiy
# Processing Record 39 of Set 14 | puerto penasco
# Processing Record 40 of Set 14 | mana
# Processing Record 41 of Set 14 | saint-francois
# Processing Record 42 of Set 14 | carutapera
# Processing Record 43 of Set 14 | sola
# Processing Record 44 of Set 14 | guaymango
# Processing Record 45 of Set 14 | puerto leguizamo
# Processing Record 46 of Set 14 | berlevag
# Processing Record 47 of Set 14 | ambilobe
# Processing Record 48 of Set 14 | kasongo-lunda
# Processing Record 49 of Set 14 | haverfordwest
# Processing Record 50 of Set 14 | ojinaga
# Processing Record 1 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 2 of Set 15 | nemuro
# Processing Record 3 of Set 15 | gondar
# Processing Record 4 of Set 15 | wanaka
# Processing Record 5 of Set 15 | roebourne
# Processing Record 6 of Set 15 | dharchula
# Processing Record 7 of Set 15 | petrolandia
# City not found. Skipping...
# Processing Record 8 of Set 15 | masallatah
# Processing Record 9 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 15 | evensk
# Processing Record 11 of Set 15 | acari
# Processing Record 12 of Set 15 | muisne
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | quatre cocos
# Processing Record 15 of Set 15 | myaundzha
# Processing Record 16 of Set 15 | ridgecrest
# Processing Record 17 of Set 15 | kushima
# Processing Record 18 of Set 15 | vung tau
# Processing Record 19 of Set 15 | ambon
# Processing Record 20 of Set 15 | vigrestad
# Processing Record 21 of Set 15 | debre birhan
# Processing Record 22 of Set 15 | candido mendes
# Processing Record 23 of Set 15 | katangli
# Processing Record 24 of Set 15 | balkanabat
# Processing Record 25 of Set 15 | novopetrovskoye
# Processing Record 26 of Set 15 | okhotsk
# Processing Record 27 of Set 15 | itaituba
# Processing Record 28 of Set 15 | atar
# Processing Record 29 of Set 15 | jalu
# Processing Record 30 of Set 15 | cardston
# Processing Record 31 of Set 15 | broken hill
# Processing Record 32 of Set 15 | pueblo nuevo solistahuacan
# Processing Record 33 of Set 15 | ca mau
# Processing Record 34 of Set 15 | kalmunai
# Processing Record 35 of Set 15 | southend-on-sea
# Processing Record 36 of Set 15 | kemise
# Processing Record 37 of Set 15 | jubayl
# City not found. Skipping...
# Processing Record 38 of Set 15 | jiayuguan
# Processing Record 39 of Set 15 | miass
# Processing Record 40 of Set 15 | kulunda
# Processing Record 41 of Set 15 | aksu
# Processing Record 42 of Set 15 | zwedru
# Processing Record 43 of Set 15 | xingcheng
# Processing Record 44 of Set 15 | dunedin
# Processing Record 45 of Set 15 | tatui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Torbay      CA  47.6666  -52.7314     62.76        90          90
# 1      Mount Isa      AU -20.7333  139.5000     51.57        37           4
# 2          Along      IN  28.1667   94.7667     77.61        99         100
# 3    Belaya Gora      RU  68.5333  146.4167     46.49        68          91
# 4      De-Kastri      RU  51.4667  140.7833     65.19        90         100
# 5        Rikitea      PF -23.1203 -134.9692     69.89        65          96
# 6          Andra      RU  62.5147   65.8878     55.56        57          10
# 7  San Cristobal      VE   7.7669  -72.2250     68.18        76         100
# 8        Ushuaia      AR -54.8000  -68.3000     37.06        81          40
# 9        Erdenet      MN  49.0333  104.0833     54.52        84          95
#
#    Wind Speed Current Description
# 0        8.05     overcast clouds
# 1        4.61           clear sky
# 2        0.89     overcast clouds
# 3        7.56     overcast clouds
# 4        5.21          light rain
# 5        4.07     overcast clouds
# 6       12.12           clear sky
# 7        4.41     overcast clouds
# 8        9.22    scattered clouds
# 9        4.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
